# %% [markdown]
# **Files,exceptional handling,logging and memory managment Question**

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
#
# Ans:
# **COMPLIED LANGUAGE:**
# * A compiled language is a programming
# language whose implement are typically compilers and not interpreters.
# * In this language, once the program is compiled it is expressed in the instructions of the target machine.
# * In this language, compiled programs run faster than interpreted programs.
# * The code of compiled language can be executed directly by the computer’s CPU.
#
# **INTERPRETED LANGUAGE:**
# * An interpreted language is a programming language whose implementations execute instructions directly and freely, without previously compiling a program into machine-language instructions.
# * While in this language, the instructions are not directly executed by the target machine.
# * While in this language, interpreted programs can be modified while the program is running.
# * In this languages, all the debugging occurs at run-time.

# %% [markdown]
# 2.**What is exception handling in Python?**
#
# Ans: Exception handling is a technique in Python for dealing with errors that occur during program execution. It entails spotting potential error situations, responding appropriately to exceptions when they arise, and identifying possible error conditions. Using the try and except keywords, Python provides a structured approach to exception handling.

# %% [markdown]
# ![3520231125173608.png](data:image/png;base64,...)

# %% [markdown]
# 3. **What is the purpose of the finally block in exception handling?**
# Ans: Exceptions are errors that occur at runtime when the program is being executed. They are usually caused by invalid user input or code that is invalid in Python. Exception handling allows the program to continue to execute even if an error occurs.

# %% [markdown]
# 4. **What is logging in Python?**
# Ans: Logging is a Python module in the standard library that provides the facility to work with the framework for releasing log messages from the Python programs. Logging is used to tracking events that occur when the software runs.
#
# **Python logging levels:**
# * Debug: These are used to give Detailed information, typically of interest only when diagnosing problems.
# * Info: These are used to confirm that things are working as expected.
# * Warning: These are used as an indication that something unexpected happened, or is indicative of some problem in the near future.
# * Error: This tells that due to a more serious problem, the software has not been able to perform some function
# * Critical: This tells serious error, indicating that the program itself may be unable to continue running

# %% [markdown]
# 5. **What is the significance of the __del__ method in Python?**
#
# Ans:
# The __del__ method is a special method in Python that is called when an object is about to be destroyed. It allows you to define specific cleanup actions that should be taken when an object is garbage collected. This method can be particularly useful for releasing external resources such as file handles, network connections, or database connections that the object may hold.
#
# **syntax: **
# class ClassName:
#     def __del__(self):
#     #cleanup code
#     pass
#
# **Purpose:**The __del__ method is used to define the actions that should be performed before an object is destroyed. This can include releasing external resources such as files or database connections associated with the object.

# %% [markdown]
# 6. **What is the difference between import and from ... import in Python?**
#
# Ans:
# **import:**
# * Imports the entire module. This means you gain access to all the functions, classes, and variables defined in that module.
# * Requires you to use the module name as a prefix. To access a specific attribute, you need to use the module name followed by a dot (.).
#
# example:
# import math
#
# result = math.sqrt(25)
#
# **from ... import:**
# * Imports specific attributes from a module. This allows you to directly use those attributes without needing the module name prefix.
# *  Can be more concise. It's useful when you only need a few specific things from a module
#
# example:
# from math import sqrt
#
# result = sqrt(25)

# %% [markdown]
# 7. ** How can you handle multiple exceptions in Python?**
#
# Ans: If you can handle different exceptions all using a single block of code, they can be grouped together in a tuple as shown in the code given below :

# %%
#code 1
# uaing a single except cliuse with multiple exceptions in a few ways:

try:
    # code that might raise exceptions
except (ValueError, IndexError, KeyError) as e:
    # code to handle the exceptions

# %% [markdown]
# This approach catches any of the listed exceptions and handles them with the same code block.

# %%
#using multiple except cluses
try:
    # code that might raise exceptions
except ValueError:
    # code to handle ValueError
except IndexError:
    # code to handle IndexError
except KeyError:
    # code to handle KeyError

# %% [markdown]
# This approach allows you to handle each exception type differently.

# %%
# using a generic except clause
try:
    # code that might raise exceptions
except Exception as e:
    # code to handle any exception
    ...

# %% [markdown]
# This approach catches any exception, but it's generally recommended to be more specific with your exception handling

# %%
#Using else and finally clauses:
try:
    # code that might raise exceptions
except ValueError:
    # code to handle ValueError
else:
    # code to run if no exceptions were raised
finally:
    # code to run regardless of whether an exception was raised

# %% [markdown]
# The else clause executes only if no exception is raised. The finally clause executes regardless of whether an exception was raised or not, making it useful for cleanup tasks.

# %% [markdown]
# 8. ** What is the purpose of the with statement when handling files in Python?**
# Ans:
#
# * The with statement in Python replaces a try-catch block with a simple shorthand.
#
# * More significantly, it ensures that resources are closed immediately after processing.
#
# * Reading or writing to a file is a common use of the with statement.
#
# * A context manager is a function or class that supports the with statement. A context manager enables you to open and close resources right when you want to.
#
# * The open() function, for example, is a context manager. When you use the with statement to call the open() function, the file closes automatically after you've processed it.

# %%
#example

# 1) without using with statement
file = open('file_path', 'w')
file.write('hello world !')
file.close()

# 2) without using with statement
file = open('file_path', 'w')
try:
    file.write('hello world')
finally:
    file.close()

# %% [markdown]
# 9. **What is the difference between multithreading and multiprocessing?**
#
# Ans:
# **MULTIPROCESSING**
#
# * In Multiprocessing, CPUs are added for increasing computing power.
#
# * In Multiprocessing, Many processes are executed simultaneously.
#
# * Multiprocessing are classified into Symmetric and Asymmetric.
#
# * In Multiprocessing, Process creation is a time-consuming process.
#
# * In Multiprocessing, every process owned a separate address space.
#
# **MULTITHREADING**
#
# * While In Multithreading, many threads are created of a single process for increasing computing power.
#
# * While in multithreading, many threads of a process are executed simultaneously.
#
# * While Multithreading is not classified in any categories.
#
# * While in Multithreading, process creation is according to economical.
#
# * While in Multithreading, a common address space is shared by all the threads.

# %% [markdown]
# 10. **What are the advantages of using logging in a program?**
#
# Ans:
# * Debugging: Logging can help you understand what your program did, what went wrong, and how to fix it.
#
# * Contextual information: Logging provides contextual information, such as the message's origin, timestamp, and logging levels.
#
# * Filter objects: Filter objects allow you to selectively include or exclude log messages based on specific criteria.
#
# * Tracking errors: Logging can help you record information about errors, warnings, and other events that occur during program execution.

# %% [markdown]
# 11. **What is memory management in Python?**
#
# Ans: In Python, memory management is automatic, it involves handling a private heap that contains all Python objects and data structures. The Python memory manager internally ensures the efficient allocation and deallocation of this memory.
#
# **Memory Management Components**
# * Private Heap: Acts as the main storage for all Python objects and data. It is managed internally by the Python memory manager.
#
# * Raw Memory Allocator: This low-level component directly interacts with the operating system to reserve memory space in Python's private heap. It ensures there's enough room for Python's data structures and objects.
#
# * Object-Specific Allocators: On top of the raw memory allocator, several object-specific allocators manage memory for different types of objects, such as integers, strings, tuples, and dictionaries.
#
# Meomery Mnagment in Python allocation in two type - stack and heap
#
# **Stack − Static Memory Allocation**
# In static memory allocation, memory is allocated at compile time and stored in the stack. This is typical for function call stacks and variable references. The stack is a region of memory used for storing local variables and function call information. It operates on a Last-In-First-Out (LIFO) basis, where the most recently added item is the first to be removed.
#
# **Heap − Dynamic Memory Allocation**
# Dynamic memory allocation occurs at runtime for objects and data structures of non-primitive types. The actual data of these objects is stored in the heap, while references to them are stored on the stack.

# %% [markdown]
# 12. **What are the basic steps involved in exception handling in Python?**
#
# Ans:
# Exception handeling in python involves the following basic steps:
#
# * try : enclosed the code that might raise an exception whinin a try block.
#
# * except: define one or more except blocks to handle specific exceptions.
#
# * else: Optionally include an else block to excute code if no exception occurs.
#
# * finally: optionally include a finally block to execute code regardless of whether an exception occured.

# %%
try:
    # Code that might raise an exception
    x = 10 / 0
except ZeroDivisionError:
    # Handle the exception
    print("Division by zero error occurred.")
else:
    # Execute if no exception occurred
    print("No exception occurred.")
finally:
    # Execute regardless of exception
    print("Finally block executed.")

# %% [markdown]
# 13. **Why is memory management important in Python?**
#
# Ans:
#
# * Efficient Resource Utilization:
# Proper memory management ensures that your Python programs use memory efficiently, avoiding unnecessary memory consumption. This is crucial for applications that handle large datasets or run for extended periods.
#
# * Preventing Memory Leaks:
# Memory leaks occur when objects are no longer needed but are not deallocated, leading to a gradual increase in memory usage. Python's garbage collector helps prevent memory leaks, but understanding memory management can help you write code that minimizes the risk of leaks occurring.
#
# * Improved Performance:
# Efficient memory usage can lead to improved performance. When memory is managed well, there's less overhead from garbage collection and less need to swap memory to disk, resulting in faster program execution.
#
# *  Debugging:
# When you encounter memory-related issues, knowing how Python manages memory can help you diagnose and resolve them more effectively.

# %% [markdown]
# 14. **What is the role of try and except in exception handling?**
#
# Ans:
# **Role of try:**
# The try block contains the code that might raise an exception. Python executes this block of code normally, but if an exception occurs, the rest of the try block is skipped, and the program jumps to the corresponding except block.
#
# **
# In Python, try and except are key components of exception handling. They allow you to handle errors gracefully and prevent your program from crashing when unexpected situations arise.
#
# Role of try
# The try block contains the code that might raise an exception. Python executes this block of code normally, but if an exception occurs, the rest of the try block is skipped, and the program jumps to the corresponding except block.
#
# **Role of except:**
# The except block defines how to handle a specific exception. If an exception occurs in the try block, Python searches for a matching except block to handle it. This block is executed, allowing the program to recover or perform cleanup actions.

# %%
#basic syntax
try:
    # Code that might raise an exception
    risky_operation()
except SpecificException as e:
    # Code to handle the exception
    print(f"An error occurred: {e}")

# %%
#example:
try:
    # Attempting to divide by zero
    result = 10 / 0
except ZeroDivisionError:
    # Handling the exception
    print("Division by zero is not allowed.")
# Out:
# Division by zero is not allowed.

# %% [markdown]
# 15. ** How does Python's garbage collection system work?**
#
# Ans:
# When attempting to add an object to a reference counter, a cyclical reference or reference cycle is produced. Because the object’s reference counter could never reach 0 (due to cycle), a reference counter cannot destroy the object. Therefore, in situations like this, we employ the universal waste collector. It operates and releases the memory used. A Generational Garbage Collector can be found in the standard library’s gc module.
#
# garbage collection are many type:
#
# * Automatic Garbage Collection of Cycles
# * Manual Garbage Collection
# * Forced Garbage Collection
# * Disabling Garbage Collection
# * Interacting with Python Garbage Collector

# %%
import gc

# get the current collection
# thresholds as a tuple
print("Garbage collection thresholds:",
                    gc.get_threshold())
# Out:
# Garbage collection thresholds: (700, 10, 10)

# %% [markdown]
# 16. **What is the purpose of the else block in exception handling?**
#
# Ans: The else block in exception handling is used to define code that should run only if no exceptions occur in the try block. It provides a way to separate the "successful execution" logic from the exception-handling logic, making the code more readable and organized.
#
# **Purpose of the else Block**
# 1. clear separation of logic:
# * The try block contains code that might raise an exception.
# * The except block handles any errors that occur.
# * The else block contains code that should only run if the try block completes without any errors.
#
# 2. Avoids Redundant Error Handling:
# Code in the else block is not executed if an exception occurs, so you don't need to worry about handling errors in it.
#
# 3. Improves Code Readability:
# It clearly indicates the part of the code that executes only when no exceptions are raised.

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ValueError:
    print("Invalid input! Please enter a number.")
except ZeroDivisionError:
    print("Division by zero is not allowed.")
else:
    print(f"Division successful. Result: {result}")
# Out:
# Enter a number: 2.0
# Invalid input! Please enter a number.

# %% [markdown]
# 17. **What are the common logging levels in Python?**
#
# Ans:
# The are five built - in levels of the log message.
#
# * Debug: These are used to give Detailed information, typically of interest only when diagnosing problems.
#
# * Info: These are used to confirm that things are working as expected.
#
# * Warning: These are used as an indication that something unexpected happened, or is indicative of some problem in the near future.
#
# * Error: This tells that due to a more serious problem, the software has not been able to perform some function.
#
# * Critical: This tells serious error, indicating that the program itself may be unable to continue running.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 18. **What is the difference between os.fork() and multiprocessing in Python?**
#
# Ans:
# 1. **os.fork()**
# A low-level system call that creates a child process by duplicating the current process. It is available on Unix-based systems (Linux, macOS) but not on Windows.
#
# **How it Works**
# * The child process is an almost exact copy of the parent process.
# * Both processes start executing from the point where the fork() call is made.
# * The child process gets a unique Process ID (PID).

# %%
import os

pid = os.fork()

if pid == 0:
    # Child process
    print("This is the child process.")
else:
    # Parent process
    print(f"This is the parent process. Child PID: {pid}")
# Out:
# This is the child process.
# This is the parent process. Child PID: 10249

# %% [markdown]
# **Key Characteristics:**
# * Low-level: Requires manual management of processes.
#
# * Platform-dependent: Works only on Unix-like systems.
#
# * Memory Sharing: The parent and child processes do not share memory after the fork (they are isolated copies of the process).
#
#
# 2. **multiprocessing Module:**
# A high-level module in Python's standard library for spawning and managing processes. It provides a platform-independent interface for parallelism.
#
# * Uses the operating system's native process creation mechanisms.
#
# * Allows creating separate processes using the Process class.
#
# * Supports data sharing and inter-process communication via Queue, Pipe, and Value/Array objects.

# %%
from multiprocessing import Process

def worker():
    print("This is a worker process.")

if __name__ == "__main__":
    p = Process(target=worker)
    p.start()  # Start the process
    p.join()   # Wait for it to finish
    print("Parent process done.")

# %% [markdown]
# Key Characteristics:
#
# * High-level: Abstracts away the complexity of managing processes.
#
# * Cross-platform: Works on both Unix and Windows systems.

# %% [markdown]
# 19. **What is the importance of closing a file in Python?**
#
# Ans: The Python File close() method closes the currently opened file. It is common knowledge that if a file is opened to perform a task on it, then it must be closed once the task is done. This is to make sure the amount of open files on an operating system do not exceed the limit it sets.
#
# Closing a file is necessary in an operating system as leaving too many files open can be prone to vulnerabilities and might cause data loss. Therefore, apart from this method, Python automatically closes a file when the reference object of a file is reassigned to another file. However, it is still recommended to use the close() method to close a file in a proper way.
#
# Note: This method can be called multiple times in a program.
#
# syntax:
# Following is the syntax for the Python close() method −

# %% [markdown]
# 20. **What is the difference between file.read() and file.readline() in Python?**
#
# Ans:
# **file.read(size = -1)**
# purpose: reads the entire content of the file or a specified number of bytes.
#
# Behavior:
# * if size is not provided or is set to -1, it reads the entire file content as a single string.
#
# * if size is specified, it reads up to size bytes or  characters.
#
# use case: suitable when you need to read whole file or a specific amount of data at once.

# %%
with open("example.txt", "r") as file:
    content = file.read()  # Reads the entire file
    print(content)

# %% [markdown]
# **Key Characteristics:**
# * Reads all or part of the file into memory.
#
# * Returns the data as a single string.
#
# * May consume significant memory for large files.

# %% [markdown]
# 2. **file.readline(size=-1)**
#
# purpose: reads a single line from the file, up to the newline character(\n).
#
# Behavior:
# * Reads one line at a time, stopping at the first newline character.
#
# * If size is specified, it reads up to size characters of the line, even if it doesn't reach the newline.
#
# * If called repeatedly, it reads the next line each time.

# %%
with open("example.txt", "r") as file:
    line = file.readline()  # Reads the first line
    print(line)

# %% [markdown]
# **Key Characteristics:**
# * Reads only one line at a time, making it memory-efficient for large files.
# * Returns the line as a string, including the newline character (\n), unless it's the last line.

# %% [markdown]
# 21. **What is the logging module in Python used for?**
#
# Ans:
# Python logging is a module that allows you to track events that occur while your program is running. You can use logging to record information about errors, warnings, and other events that occur during program execution. And logging is a useful tool for debugging, troubleshooting, and monitoring your program.
#
# How Does Logging in Python Work:
# Python import logging is a powerful tool for debugging and troubleshooting code. By default, Python will log all messages to the standard output stream. However, it is also possible to configure Python to log messages to a file, or even to a remote server.
#
# * Choose a logger - This is where the object that will actually do the logging.
#
# * Configure the logger - This step involves telling the logger to log messages, what format to use, and what level of detail to include.
#
# * Use the logger - This step simply involves using the logger object in your code to log messages.

# %% [markdown]
# 22. **What is the os module in Python used for in file handling?**
#
# Ans:
# The OS module in Python provides functions for interacting with the operating system. OS comes under Python’s standard utility modules. This module provides a portable way of using operating system-dependent functionality.
#
# The *os* and *os.path* modules include many functions to interact with the file system.
#
# **Python-OS-Module Functions**
#
# * Handling the Current Working Directory
# * Creating a Directory
# * Listing out Files and Directories with Python
# * Deleting Directory or Files using Python

# %% [markdown]
# 23. **What are the challenges associated with memory management in Python?**
#
# Ans:
# Memory management in Python involves the management of a private heap. A private heap is a portion of memory that is exclusive to the Python process. All Python objects and data structures are stored in the private heap.
#
# *Memory management problems. The basic problem in managing memory is knowing when to keep the data it contains, and when to throw it away so that the memory can be reused.*
#
# A. **Memery Leaks:**
# Circular References: When objects reference each other, creating a cycle, their reference counts never reach zero even if they are no longer accessible. This prevents the garbage collector from reclaiming their memory, leading to memory leaks.
#
# Unintended References: Holding onto references to large objects or data structures longer than necessary can prevent their deallocation, causing memory usage to grow unnecessarily.
#
# ** Lack of Fine-Grained Control:**
# Limited Manual Control:
# Unlike languages like C or C++, Python doesn't give developers direct control over memory allocation and deallocation. This can be limiting in situations where precise memory management is crucial for performance optimization.
#
# **Performance Impact:**
# Garbage Collection Pauses:
# As mentioned above, garbage collection can introduce pauses in program execution. This can be problematic for real-time applications or systems where consistent performance is critical.
#
# Memory Fragmentation:
# Over time, memory allocations and deallocations can lead to fragmentation, where free memory becomes scattered in small chunks. This can make it difficult to allocate large contiguous blocks of memory, potentially impacting performance.

# %% [markdown]
# 24. **How do you raise an exception manually in Python?**
#
# Ans:
#
# *raise an exception*
# As a Python developer you can choose to throw an exception if a condition occurs.
#
# To throw (or raise) an exception, use the raise keyword.

# %%
x = -1

if x < 0:
  raise Exception("Sorry, no numbers below zero")

# %% [markdown]
# The raise keyword is used to raise an exception.
#
# You can define what kind of error to raise, and the text to print to the user.

# %% [markdown]
# 25. **Why is it important to use multithreading in certain applications?**
#
# Ans: Multithreading is a function of the CPU that permits multiple threads to run independently while sharing the same process resources. A thread is a conscience sequence of instructions that may run in the same parent process as other threads.
#
# **Benefits of Multithreading**
# * Responsiveness
# * Resource Sharing
# * Economy
# * Scalability
# * Better Communication
# * Utilization of multiprocessor architecture
# * Minimized system resource usage

# %% [markdown]
# # **Practical Questions**

# %% [markdown]
# 1. **How can you open a file for writing in Python and write a string to it?**
#
#
#
# 1.   Open the File: Use the open() function with the appropriate mode. Use 'w' mode to open the file for writing.
# 2.   Loop Through Data: Use a for loop to iterate over the data you want to write to the file.
# 3. Write Data: Use the file object’s write() method to write each piece of data to the file.

# %%
# open the file in write to the file
# Data to be written to the file
data = ["This is line 1", "This is line 2", "This is line 3"]

# Writing to a file
with open('file.txt', 'w') as f:
    for line in data:
        f.write(line + '\n')  # Write each line followed by a newline character

# The file is automatically closed when the 'with' block ends
print(data)
# Out:
# ['This is line 1', 'This is line 2', 'This is line 3']

# %% [markdown]
# 2. **Write a Python program to read the contents of a file and print each line?**

# %%
L = ["Bikram\n", "Raj\n", "Samrat\n"]

# Writing to file
file1 = open('myfile.txt', 'w')
file1.writelines(L)
file1.close()

# Opening file
file1 = open('myfile.txt', 'r')
count = 0

# Using for loop
print("Using for loop")
for line in file1:
    count += 1
    print("Line{}: {}".format(count, line.strip()))

# Closing files
file1.close()
# Out:
# Using for loop
# Line1: Bikram
# Line2: Raj
# Line3: Samrat

# %% [markdown]
# 3. ** How would you handle a case where the file doesn't exist while trying to open it for reading?**

# %%
try:
    with open("nonexistent_file.txt", "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("Error: The file does not exist. Please check the file path and try again.")
# Out:
# Error: The file does not exist. Please check the file path and try again.

# %% [markdown]
# 4. **Write a Python script that reads from one file and writes its content to another file**

# %%
def copy_file(source_file, destination_file):
    """Copies the content of one file to another."""

    try:
        with open(source_file, 'r') as source, open(destination_file, 'w') as destination:
            for line in source:
                destination.write(line)
        print(f"File copied successfully from '{source_file}' to '{destination_file}'")
    except FileNotFoundError:
        print(f"Error: Source file '{source_file}' not found.")

if __name__ == "__main__":
    source_file = "source.txt"  # Replace with your source file name
    destination_file = "destination.txt"  # Replace with your destination file name

    copy_file(source_file, destination_file)
# Out:
# Error: Source file 'source.txt' not found.

# %% [markdown]
# 5. ** How would you catch and handle division by zero error in Python**

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero")
# Out:
# Error: Division by zero

# %% [markdown]
# 6. ** Write a Python program that logs an error message to a log file when a division by zero exception occurs.**

# %%
import logging

# Configure the logger
logging.basicConfig(filename='app.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

try:
    result = 10 / 0
except ZeroDivisionError as e:
    logging.error("Division by zero error occurred: {}".format(e))
# Out:
# ERROR:root:Division by zero error occurred: division by zero

# %% [markdown]
# 7. **How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?**

# %%
import logging

# Configure the logging system
logging.basicConfig(
    level=logging.DEBUG,  # Set the minimum logging level
    format="%(asctime)s - %(levelname)s - %(message)s",  # Log format
    filename="app.log",  # Log to a file instead of the console
    filemode="w",  # Overwrite the log file each time
)

# Log messages at different levels
logging.debug("This is a DEBUG message: useful for debugging.")
logging.info("This is an INFO message: general program information.")
logging.warning("This is a WARNING message: something unexpected happened.")
logging.error("This is an ERROR message: an error occurred in the program.")
logging.critical("This is a CRITICAL message: a severe error occurred.")
# Out:
# WARNING:root:This is a WARNING message: something unexpected happened.
# ERROR:root:This is an ERROR message: an error occurred in the program.
# CRITICAL:root:This is a CRITICAL message: a severe error occurred.

# %% [markdown]
# 8. **Write a program to handle a file opening error using exception handling.**

# %%
def read_file(file_path):
    try:
        # Attempt to open and read the file
        with open(file_path, "r") as file:
            content = file.read()
            print("File content:\n")
            print(content)
    except FileNotFoundError:
        # Handle case where the file does not exist
        print(f"Error: The file '{file_path}' does not exist.")
    except PermissionError:
        # Handle case where there are insufficient permissions to open the file
        print(f"Error: Permission denied for accessing the file '{file_path}'.")
    except Exception as e:
        # Handle any other unexpected exceptions
        print(f"An unexpected error occurred: {e}")

# Example usage
if __name__ == "__main__":
    # User-provided file path
    file_path = input("Enter the path of the file to open: ")
    read_file(file_path)
# Out:
# Enter the path of the file to open: nonexistent_file.txt
# Error: The file 'nonexistent_file.txt' does not exist.

# %% [markdown]
# 9. **How can you read a file line by line and store its content in a list in Python?**

# %%
L = ["Gate\n", "IIT\n", "Sucess\n"]

# writing to file
file1 = open('myfile.txt', 'w')
file1.writelines(L)
file1.close()

# Using readlines()
file1 = open('myfile.txt', 'r')
Lines = file1.readlines()

count = 0
# Strips the newline character
for line in Lines:
    count += 1
    print("Line{}: {}".format(count, line.strip()))
# Out:
# Line1: Gate
# Line2: IIT
# Line3: Sucess

# %% [markdown]
# 10. ** How can you append data to an existing file in Python**

# %%
file1 = open("myfile.txt", "w")
L = ["Chalo Ladakh \n", "Chalo Meghalaya\n", "Chalo Kashmir"]
file1.writelines(L)
file1.close()

# Append-adds at last
file1 = open("myfile.txt", "a")  # append mode
file1.write("Today \n")
file1.close()

file1 = open("myfile.txt", "r")
print("Output of Readlines after appending")
print(file1.read())
print()
file1.close()

# Write-Overwrites
file1 = open("myfile.txt", "w")  # write mode
file1.write("Tomorrow \n")
file1.close()

file1 = open("myfile.txt", "r")
print("Output of Readlines after writing")
print(file1.read())
print()
file1.close()
# Out:
# Output of Readlines after appending
# Chalo Ladakh
# Chalo Meghalaya
# Chalo KashmirToday
#
#
# Output of Readlines after writing
# Tomorrow

# %% [markdown]
# 11. **Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist.**

# %%
def get_value_from_dict(dictionary, key):
    try:
        # Attempt to access the specified key
        value = dictionary[key]
        print(f"The value for key '{key}' is: {value}")
    except KeyError:
        # Handle the case where the key doesn't exist
        print(f"Error: The key '{key}' does not exist in the dictionary.")
    except Exception as e:
        # Handle any other unexpected exceptions
        print(f"An unexpected error occurred: {e}")

# Example usage
if __name__ == "__main__":
    # Sample dictionary
    sample_dict = {
        "name": "Alice",
        "age": 30,
        "city": "New York"
    }

    # Prompt user for a key to look up
    key = input("Enter the key to look up: ")
    get_value_from_dict(sample_dict, key)
# Out:
# Enter the key to look up: name
# The value for key 'name' is: Alice

# %% [markdown]
# 12. **Write a program that demonstrates using multiple except blocks to handle different types of exceptions**

# %%
def demonstrate_exceptions():
    try:
        # Prompt user for a number and perform division
        numerator = int(input("Enter the numerator: "))
        denominator = int(input("Enter the denominator: "))
        result = numerator / denominator
        print(f"The result of division is: {result}")

        # Access a dictionary
        sample_dict = {"name": "Bikram", "age": 30}
        key = input("Enter the key to look up in the dictionary: ")
        value = sample_dict[key]
        print(f"The value for key '{key}' is: {value}")

    except ValueError:
        # Handle invalid input (non-integer values)
        print("Error: Please enter a valid integer.")

    except ZeroDivisionError:
        # Handle division by zero
        print("Error: Division by zero is not allowed.")

    except KeyError:
        # Handle missing dictionary keys
        print("Error: The specified key does not exist in the dictionary.")

    except Exception as e:
        # Handle any other unexpected exceptions
        print(f"An unexpected error occurred: {e}")

# Run the program
if __name__ == "__main__":
    demonstrate_exceptions()
# Out:
# Enter the numerator: 10
# Enter the denominator: 2
# The result of division is: 5.0
# Enter the key to look up in the dictionary: name
# The value for key 'name' is: Bikram

# %% [markdown]
# 13. **How would you check if a file exists before attempting to read it in Python**

# %%
import os

file_path = "path/to/your/file.txt"

if os.path.exists(file_path):
    # File exists, proceed with reading
    with open(file_path, "r") as file:
        # Read the file content
        content = file.read()
else:
    # File does not exist, handle accordingly
    print("File not found:", file_path)
# Out:
# File not found: path/to/your/file.txt

# %% [markdown]
# 14. **Write a program that uses the logging module to log both informational and error messages**

# %%
import logging

# Configure the logging system
logging.basicConfig(
    level=logging.DEBUG,  # Set the logging level to log all messages from DEBUG and above
    format="%(asctime)s - %(levelname)s - %(message)s",  # Define log message format
    filename="app.log",  # Log messages will be written to this file
    filemode="w",  # Overwrite the log file each time
)

def perform_operations():
    logging.info("Program started.")  # Log an informational message

    try:
        # Example 1: Division operation
        logging.info("Attempting to perform division.")
        numerator = 10
        denominator = 0  # This will cause a ZeroDivisionError
        result = numerator / denominator
        logging.info(f"Division successful. Result: {result}")

    except ZeroDivisionError:
        logging.error("Error: Division by zero occurred.")

    try:
        # Example 2: Dictionary key access
        logging.info("Attempting to access a dictionary key.")
        sample_dict = {"name": "Alice", "age": 30}
        value = sample_dict["city"]  # This will cause a KeyError
        logging.info(f"Key access successful. Value: {value}")

    except KeyError:
        logging.error("Error: Key 'city' does not exist in the dictionary.")

    logging.info("Program finished.")  # Log an informational message at the end

# Run the program
if __name__ == "__main__":
    perform_operations()
# Out:
# ERROR:root:Error: Division by zero occurred.
# ERROR:root:Error: Key 'city' does not exist in the dictionary.

# %% [markdown]
# 15. **Write a Python program that prints the content of a file and handles the case when the file is empty**

# %%
def print_file_content(file_path):
    try:
        # Open the file in read mode
        with open(file_path, "r") as file:
            content = file.read()

            # Check if the file is empty
            if not content:
                print("The file is empty.")
            else:
                print("File content:")
                print(content)

    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")
    except PermissionError:
        print(f"Error: Permission denied for accessing the file '{file_path}'.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage
if __name__ == "__main__":
    file_path = input("Enter the path of the file to read: ")
    print_file_content(file_path)
# Out:
# Enter the path of the file to read: example.txt
# Error: The file 'example.txt' does not exist.

# %% [markdown]
# 16. **Demonstrate how to use memory profiling to check the memory usage of a small program **

# %%
from memory_profiler import profile

@profile
def my_function():
    a = [i for i in range(10000)]
    b = [i * 2 for i in range(10000)]
    return a, b

if __name__ == "__main__":
    my_function()

# %% [markdown]
# 17. ** Write a Python program to create and write a list of numbers to a file, one number per line**
#
# Ans:

# %%
def write_numbers_to_file(numbers, filename):
    """Writes a list of numbers to a file, one number per line."""

    with open(filename, 'w') as f:
        for number in numbers:
            f.write(str(number) + '\n')

if __name__ == '__main__':
    numbers = [1, 2, 3, 4, 5]
    filename = 'numbers.txt'
    write_numbers_to_file(numbers, filename)

# %% [markdown]
# 18. ** How would you implement a basic logging setup that logs to a file with rotation after 1MB?**

# %%
import logging
from logging.handlers import RotatingFileHandler

# Create a logger
logger = logging.getLogger("MyLogger")
logger.setLevel(logging.DEBUG)  # Set the logging level to DEBUG (log everything)

# Create a rotating file handler that logs to 'my_log.log'
# Rotate the log file after it exceeds 1MB (1 * 1024 * 1024 bytes)
log_handler = RotatingFileHandler("my_log.log", maxBytes=1*1024*1024, backupCount=3)

# Create a log format
log_format = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
log_handler.setFormatter(log_format)

# Add the handler to the logger
logger.addHandler(log_handler)

# Example usage of the logger
if __name__ == "__main__":
    for i in range(10000):
        logger.debug(f"Debug message {i}")
        logger.info(f"Info message {i}")
        logger.warning(f"Warning message {i}")
        logger.error(f"Error message {i}")
        logger.critical(f"Critical message {i}")

# %% [markdown]
# 19. **Write a program that handles both IndexError and KeyError using a try-except block.**

# %%
# Creating a Dictionary
subjects = {'Sree': 'Maths',
            'Ram': 'Biology',
            'Shyam': 'Science',
            'Abdul': 'Hindi'}
# try block
try:
    print('subject of Chatur is:',
          subjects['Chatur'])
# except Block
except KeyError:
    print("Chatur's records doesn't exist")
# Out:
# Chatur's records doesn't exist

# %% [markdown]
# 20. **How would you open a file and read its contents using a context manager in Python?**

# %%
# context manager

class ContextManager():
    def __init__(self):
        print('init method called')

    def __enter__(self):
        print('enter method called')
        return self

    def __exit__(self, exc_type, exc_value, exc_traceback):
        print('exit method called')

with ContextManager() as manager:
    print('with statement block')
# Out:
# init method called
# enter method called
# with statement block
# exit method called

# %% [markdown]
# 21. **Write a Python program that reads a file and prints the number of occurrences of a specific word.**

# %%
def count_word_occurrences(file_path, word_to_count):
    try:
        with open(file_path, 'r') as file:
            content = file.read()  # Read the entire file content
            word_count = content.lower().split().count(word_to_count.lower())  # Count the word (case-insensitive)
            return word_count
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

if __name__ == "__main__":
    file_path = input("Enter the path of the file to read: ")
    word_to_count = input("Enter the word to count: ")

    word_count = count_word_occurrences(file_path, word_to_count)

    if word_count is not None:
        print(f"The word '{word_to_count}' occurs {word_count} times in the file.")
# Out:
# Enter the path of the file to read: example.txt
# Enter the word to count: python
# Error: The file 'example.txt' does not exist.

# %% [markdown]
# 22. **How can you check if a file is empty before attempting to read its contents?**

# %%
import os

def is_file_empty(file_path):
    # Method 1: Check file size using os.stat
    if os.stat(file_path).st_size == 0:
        return True
    return False

def read_file_if_not_empty(file_path):
    try:
        # First, check if the file is empty
        if is_file_empty(file_path):
            print("The file is empty.")
        else:
            # If the file is not empty, read and print its content
            with open(file_path, 'r') as file:
                content = file.read()
                print("File content:")
                print(content)
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage
if __name__ == "__main__":
    file_path = input("Enter the path of the file to read: ")
    read_file_if_not_empty(file_path)
# Out:
# Enter the path of the file to read: example.txt
# Error: The file 'example.txt' does not exist.

# %% [markdown]
# 23. **Write a Python program that writes to a log file when an error occurs during file handling.**

# %%
import logging

# Set up logging to write to a file
logging.basicConfig(
    filename='file_handling.log',  # Log file where errors will be stored
    level=logging.ERROR,           # Only log errors and above
    format='%(asctime)s - %(levelname)s - %(message)s'  # Format of the log message
)

def read_file(file_path):
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            print(content)
    except FileNotFoundError:
        logging.error(f"File '{file_path}' not found.")
        print(f"Error: The file '{file_path}' does not exist.")
    except PermissionError:
        logging.error(f"Permission denied when trying to read '{file_path}'.")
        print(f"Error: Permission denied when trying to read '{file_path}'.")
    except Exception as e:
        logging.error(f"An unexpected error occurred while reading '{file_path}': {e}")
        print(f"An unexpected error occurred: {e}")

def write_file(file_path, content):
    try:
        with open(file_path, 'w') as file:
            file.write(content)
            print(f"Content successfully written to {file_path}")
    except PermissionError:
        logging.error(f"Permission denied when trying to write to '{file_path}'.")
        print(f"Error: Permission denied when trying to write to '{file_path}'.")
    except Exception as e:
        logging.error(f"An unexpected error occurred while writing to '{file_path}': {e}")
        print(f"An unexpected error occurred: {e}")

# Example usage
if __name__ == "__main__":
    # Attempt to read a non-existent file to log an error
    file_to_read = "non_existent_file.txt"
    read_file(file_to_read)

    # Attempt to write to a file
    file_to_write = "output.txt"
    content_to_write = "This is some sample content"
    write_file(file_to_write, content_to_write)
# Out:
# ERROR:root:File 'non_existent_file.txt' not found.
# Error: The file 'non_existent_file.txt' does not exist.
# Content successfully written to output.txt
